# %%
import pickle
import keras
import numpy as np
import random
import os
import sys
import itertools
import copy
from collections import OrderedDict
from time import strftime, localtime

from helpers.data_generator import process_data, AutoEncoderDataGenerator
from helpers.hyperparam_helpers import make_bash_scripts
from helpers.custom_losses import denorm_loss, hinge_mse_loss, percent_baseline_error, baseline_MAE
from helpers.custom_losses import percent_correct_sign, baseline_MAE
from helpers.results_processing import write_autoencoder_results
import models.autoencoder
from helpers.callbacks import CyclicLR, TensorBoardWrapper, TimingCallback
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import tensorflow as tf
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %% [markdown]
# The first couple of lines defines some parameters for processing the data.

# %%
###################
# set session
###################
num_cores = 8
req_mem = 48 # gb
ngpu = 1

seed_value= 0
os.environ['PYTHONHASHSEED']=str(seed_value)
random.seed(seed_value)
np.random.seed(seed_value)
tf.set_random_seed(seed_value)

config = tf.ConfigProto(intra_op_parallelism_threads=4*num_cores,
                        inter_op_parallelism_threads=4*num_cores,
                        allow_soft_placement=True,
                        device_count={'CPU': 1,
                                      'GPU': ngpu})
session = tf.Session(config=config)
K.set_session(session)

# %% [markdown]
# The following line sets the directory.

# %%
###############
# global stuff
###############

checkpt_dir = os.path.expanduser("~/test_run/")
if not os.path.exists(checkpt_dir):
    os.makedirs(checkpt_dir)

# %% [markdown]
# This part of the code defines the scenarios.

# %%
###############
# scenarios
###############

efit_type = 'EFIT02'

default_scenario = {'actuator_names': ['pinj', 'curr', 'tinj','gasA'],
                    'profile_names': ['temp',
                                      'dens',
                                      'ffprime_{}'.format(efit_type),
                                      'press_{}'.format(efit_type),
                                      'q_{}'.format(efit_type)],
                    'scalar_names': [],
                    'profile_downsample': 2,
                    'state_encoder_type': 'dense',
                    'state_decoder_type': 'dense',
                    'control_encoder_type': 'dense',
                    'control_decoder_type': 'dense',
                    'state_encoder_kwargs': {'num_layers': 6,
                                             'layer_scale': 2,
                                             'std_activation':'relu'},
                    'state_decoder_kwargs': {'num_layers': 6,
                                             'layer_scale': 2,
                                             'std_activation':'relu'},
                    'control_encoder_kwargs': {'num_layers': 10,
                                               'layer_scale': 2,
                                               'std_activation':'relu'},
                    'control_decoder_kwargs': {'num_layers': 10,
                                               'layer_scale': 2,
                                               'std_activation':'relu'},
                    'state_latent_dim':50,
                    'control_latent_dim':5,
                    'x_weight':1,
                    'u_weight':1,
                    'discount_factor':1,
                    'batch_size': 10,
                    'epochs': 3,
                    'flattop_only': True,
                    'raw_data_path': '/scratch/gpfs/jabbate/small_data.pkl', #/scratch/gpfs/jabbate/mixed_data/final_data.pkl #'/projects/EKOLEMEN/profile_predictor/DATA/full_data_with_error/small_data.pkl',
                    'process_data': True,
                    'optimizer': 'adagrad',
                    'optimizer_kwargs': {},
                    'shuffle_generators': True,
                    'pruning_functions': ['remove_nan', 'remove_dudtrip', 'remove_I_coil'],
                    'normalization_method': 'RobustScaler',
                    'window_length': 3,
                    'window_overlap': 0,
                    'lookback': 0,
                    'lookahead': 3,
                    'sample_step': 1,
                    'uniform_normalization': True,
                    'train_frac': 0.8,
                    'val_frac': 0.2,
                    'nshots': 12000,
                    #'excluded_shots': ['topology_TOP', 'topology_OUT', 'topology_MAR', 'topology_IN', 'topology_DN', 'topology_BOT']
                   'excluded_shots': ['topology_TOP', 'topology_OUT', 'topology_MAR', 'topology_BOT']} # Including DN and IN

scenarios_dict = OrderedDict()
scenarios_dict['x_weight'] = [{'x_weight':0.1},
                              {'x_weight':1}]
scenarios_dict['u_weight'] = [{'u_weight':1},
                              {'u_weight':10}]
scenarios_dict['discount_factor'] = [{'discount_factor':1.0},
                                     {'discount_factor':0.8}]
scenarios_dict['state_latent_dim'] = [{'state_latent_dim': 20},
                                      {'state_latent_dim': 50},
                                      {'state_latent_dim': 100}]
scenarios_dict['control_latent_dim'] = [{'control_latent_dim': 5},
                                        {'control_latent_dim': 10},
                                        {'control_latent_dim': 15}]
scenarios_dict['state_encoder_kwargs'] = [{'state_encoder_kwargs': {'num_layers': 6,
                                             'layer_scale': 2,
                                             'std_activation':'elu'},
                                          'state_decoder_kwargs': {'num_layers': 6,
                                             'layer_scale': 2,
                                             'std_activation':'elu'}},
                                         {'state_encoder_kwargs': {'num_layers': 10,
                                             'layer_scale': 1,
                                             'std_activation':'elu'},
                                          'state_decoder_kwargs': {'num_layers': 10,
                                             'layer_scale': 1,
                                             'std_activation':'elu'}}]
scenarios_dict['control_encoder_kwargs'] = [{'control_encoder_kwargs': {'num_layers': 6,
                                             'layer_scale': 2,
                                             'std_activation':'elu'},
                                          'control_decoder_kwargs': {'num_layers': 6,
                                             'layer_scale': 2,
                                             'std_activation':'elu'}},
                                         {'control_encoder_kwargs': {'num_layers': 10,
                                             'layer_scale': 1,
                                             'std_activation':'elu'},
                                          'control_decoder_kwargs': {'num_layers': 10,
                                             'layer_scale': 1,
                                             'std_activation':'elu'}}]

# %% [markdown]
# The final for loop creates all combinations of the dictionary values to create all the different scenarios for the model.

# %%
scenarios = []
runtimes = []
for scenario in itertools.product(*list(scenarios_dict.values())):
    foo = {k: v for d in scenario for k, v in d.items()}
    scenarios.append(foo)
    runtimes.append(6*60)
num_scenarios = len(scenarios)

# %% [markdown]
# Scenariondex = -1 runs all scenarios. Any positive number runs only that scenario.
#
# The -1 case essentially creates different files and runs each file.
#
# The final for loop just prints the scenarios.

# %%
###############
# Batch Run
###############
scenario_index = 1

if scenario_index == -1:
    make_bash_scripts(num_scenarios, checkpt_dir,
                      num_cores, ngpu, req_mem, runtimes, mode='autoencoder')
    print('Created Driver Scripts in ' + checkpt_dir)
    for i in range(num_scenarios):
        os.system('sbatch {}'.format(os.path.join(
            checkpt_dir, 'driver' + str(i) + '.sh')))
    print('Jobs submitted, exiting')

###############
# Load Scenario and Data
###############
if scenario_index >= 0:
    verbose = 2
    print('Loading Scenario ' + str(scenario_index) + ':')
    scenario = scenarios[scenario_index]
    scenario.update(
        {k: v for k, v in default_scenario.items() if k not in scenario.keys()})
else:
    verbose = 1
    print('Loading Default Scenario:')
    scenario = default_scenario
    
for k,v in scenario.items():
    print('{}:{}'.format(k,v))
# Out:
# Loading Scenario 1:
# x_weight:0.1
# u_weight:1
# discount_factor:1.0
# state_latent_dim:20
# control_latent_dim:5
# state_encoder_kwargs:{'num_layers': 6, 'layer_scale': 2, 'std_activation': 'elu'}
# state_decoder_kwargs:{'num_layers': 6, 'layer_scale': 2, 'std_activation': 'elu'}
# control_encoder_kwargs:{'num_layers': 10, 'layer_scale': 1, 'std_activation': 'elu'}
# control_decoder_kwargs:{'num_layers': 10, 'layer_scale': 1, 'std_activation': 'elu'}
# actuator_names:['pinj', 'curr', 'tinj', 'gasA']
# profile_names:['temp', 'dens', 'ffprime_EFIT02', 'press_EFIT02', 'q_EFIT02']
# scalar_names:[]
# profile_downsample:2
# state_encoder_type:dense
# state_decoder_type:dense
# control_encoder_type:dense
# control_decoder_type:dense
# batch_size:10
# epochs:3
# flattop_only:True
# raw_data_path:/scratch/gpfs/jabbate/small_data.pkl
# process_data:True
# optimizer:adagrad
# optimizer_kwargs:{}
# shuffle_generators:True
# pruning_functions:['remove_nan', 'remove_dudtrip', 'remove_I_coil']
# normalization_method:RobustScaler
# window_length:3
# window_overlap:0
# lookback:0
# lookahead:3
# sample_step:1
# uniform_normalization:True
# train_frac:0.8
# val_frac:0.2
# nshots:12000
# excluded_shots:['topology_TOP', 'topology_OUT', 'topology_MAR', 'topology_BOT']

# %% [markdown]
# This block of code processes the data to normalize it and prepare the training and validation data. See helpers/data_generator for more info in the process_data function.

# %%
if scenario['process_data']:
    scenario['sig_names'] = scenario['profile_names'] + \
        scenario['actuator_names'] + scenario['scalar_names']

    traindata, valdata, normalization_dict = process_data(scenario['raw_data_path'],
                                                          scenario['sig_names'],
                                                          scenario['normalization_method'],
                                                          scenario['window_length'],
                                                          scenario['window_overlap'],
                                                          scenario['lookback'],
                                                          scenario['lookahead'],
                                                          scenario['sample_step'],
                                                          scenario['uniform_normalization'],
                                                          scenario['train_frac'],
                                                          scenario['val_frac'],
                                                          scenario['nshots'],
                                                          verbose,
                                                          scenario['flattop_only'],
                                                          pruning_functions=scenario['pruning_functions'],
                                                          excluded_shots=scenario['excluded_shots'])
    scenario['dt'] = np.mean(np.diff(traindata['time']))/1000 # in seconds
    scenario['normalization_dict'] = normalization_dict
# Out:
# Loading
# Signals: curr, dens, ffprime_EFIT02, gasA, pinj, press_EFIT02, q_EFIT02, temp, tinj
# Number of useable shots:  20
# Number of shots used:  20
# Total number of timesteps:  1555
# Shots with Complete NaN:
# 242 samples total
# Removing weird I-coils
# Removed 111 samples
# 131 samples remaining
# Removing NaN
# Removed 0 samples
# 131 samples remaining
# Removing dudtrip
# Removed 18 samples
# 113 samples remaining
# 113 samples remaining after pruning
# Total number of samples:  113
# Number of training samples:  90
# Number of validation samples:  23

# %% [markdown]
# The following code defines a couple of more parameters.

# %%
scenario['profile_length'] = int(
    np.ceil(65/scenario['profile_downsample']))

scenario['runname'] = 'model-autoencoder' + \
                      '_SET-' + scenario['state_encoder_type'] + \
                      '_SDT-' + scenario['state_decoder_type'] + \
                      '_CET-' + scenario['control_encoder_type'] + \
                      '_CDT-' + scenario['control_decoder_type'] + \
                      '_profiles-' + '-'.join(scenario['profile_names']) + \
                      '_act-' + '-'.join(scenario['actuator_names']) + \
                      '_LB-' + str(scenario['lookback']) + \
                      '_LA-' + str(scenario['lookahead']) +\
                      strftime("_%d%b%y-%H-%M", localtime())

if scenario_index >= 0:
    scenario['runname'] += '_Scenario-' + str(scenario_index)

print(scenario['runname'])
# Out:
# model-autoencoder_SET-dense_SDT-dense_CET-dense_CDT-dense_profiles-temp-dens-ffprime_EFIT02-press_EFIT02-q_EFIT02_act-pinj-curr-tinj-gasA_LB-0_LA-3_17Nov20-09-26_Scenario-1

# %% [markdown]
# Data generators for training and validation sets. The functions are also in helpers/data_generator.

# %%
###############
# Make data generators
###############

train_generator = AutoEncoderDataGenerator(traindata,
                                           scenario['batch_size'],
                                           scenario['profile_names'],
                                           scenario['actuator_names'],
                                           scenario['scalar_names'],
                                           scenario['lookback'],
                                           scenario['lookahead'],
                                           scenario['profile_downsample'],
                                           scenario['state_latent_dim'],
                                           scenario['discount_factor'],
                                           scenario['x_weight'],
                                           scenario['u_weight'],                                            
                                           scenario['shuffle_generators'])
val_generator = AutoEncoderDataGenerator(valdata,
                                         scenario['batch_size'],
                                         scenario['profile_names'],
                                         scenario['actuator_names'],
                                         scenario['scalar_names'],
                                         scenario['lookback'],
                                         scenario['lookahead'],
                                         scenario['profile_downsample'],
                                         scenario['state_latent_dim'],
                                         scenario['discount_factor'],
                                         scenario['x_weight'],
                                         scenario['u_weight'],
                                         scenario['shuffle_generators'])

print('Made Generators')
# Out:
# Made Generators

# %% [markdown]
# Creates models and optimizers. The make_autoencoder is from models.autoencoder.make_autoencoder

# %%
###############
# Get model and optimizer
###############
optimizers = {'sgd': keras.optimizers.SGD,
              'rmsprop': keras.optimizers.RMSprop,
              'adagrad': keras.optimizers.Adagrad,
              'adadelta': keras.optimizers.Adadelta,
              'adam': keras.optimizers.Adam,
              'adamax': keras.optimizers.Adamax,
              'nadam': keras.optimizers.Nadam}

model = models.autoencoder.make_autoencoder(scenario['state_encoder_type'],
                                            scenario['state_decoder_type'],
                                            scenario['control_encoder_type'],
                                            scenario['control_decoder_type'],
                                            scenario['state_encoder_kwargs'],
                                            scenario['state_decoder_kwargs'],
                                            scenario['control_encoder_kwargs'],
                                            scenario['control_decoder_kwargs'],
                                            scenario['profile_names'],
                                            scenario['scalar_names'],
                                            scenario['actuator_names'],
                                            scenario['state_latent_dim'],
                                            scenario['control_latent_dim'],
                                            scenario['profile_length'],
                                            scenario['lookback'],
                                            scenario['lookahead'])



model.summary()
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_temp (InputLayer)         (None, 4, 33)        0
# __________________________________________________________________________________________________
# input_dens (InputLayer)         (None, 4, 33)        0
# __________________________________________________________________________________________________
# input_ffprime_EFIT02 (InputLaye (None, 4, 33)        0
# __________________________________________________________________________________________________
# input_press_EFIT02 (InputLayer) (None, 4, 33)        0
# __________________________________________________________________________________________________
# input_q_EFIT02 (InputLayer)     (None, 4, 33)        0
# __________________________________________________________________________________________________
# input_pinj (InputLayer)         (None, 3, 1)         0
# __________________________________________________________________________________________________
# input_curr (InputLayer)         (None, 3, 1)         0
# __________________________________________________________________________________________________
# input_tinj (InputLayer)         (None, 3, 1)         0
# __________________________________________________________________________________________________
# input_gasA (InputLayer)         (None, 3, 1)         0
# __________________________________________________________________________________________________
# profile_joiner (Concatenate)    (None, 4, 165)       0           input_temp[0][0]
#                                                                  input_dens[0][0]
#                                                                  input_ffprime_EFIT02[0][0]
#                                                                  input_press_EFIT02[0][0]
#                                                                  input_q_EFIT02[0][0]
# __________________________________________________________________________________________________
# control_joiner (Concatenate)    (None, 3, 4)         0           input_pinj[0][0]
#                                                                  input_curr[0][0]
#                                                                  input_tinj[0][0]
#                                                                  input_gasA[0][0]
# __________________________________________________________________________________________________
# state_encoder_time_dist (TimeDi (None, 4, 20)        58877       profile_joiner[0][0]
# __________________________________________________________________________________________________
# ctrl_encoder_time_dist (TimeDis (None, 3, 5)         205         control_joiner[0][0]
# __________________________________________________________________________________________________
# cropping1d_38 (Cropping1D)      (None, 1, 20)        0           state_encoder_time_dist[0][0]
# __________________________________________________________________________________________________
# u (Cropping1D)                  (None, 3, 5)         0           ctrl_encoder_time_dist[0][0]
# __________________________________________________________________________________________________
# x0 (Reshape)                    (None, 20)           0           cropping1d_38[0][0]
# __________________________________________________________________________________________________
# AB_matrices (SimpleRNN)         (None, 3, 20)        500         u[0][0]
#                                                                  x0[0][0]
# __________________________________________________________________________________________________
# ctrl_decoder_time_dist (TimeDis (None, 3, 4)         214         ctrl_encoder_time_dist[0][0]
# __________________________________________________________________________________________________
# state_decoder_time_dist (TimeDi (None, 4, 165)       32052       state_encoder_time_dist[0][0]
# __________________________________________________________________________________________________
# x1 (Cropping1D)                 (None, 3, 20)        0           state_encoder_time_dist[0][0]
# __________________________________________________________________________________________________
# x1est (Reshape)                 (None, 3, 20)        0           AB_matrices[0][0]
# __________________________________________________________________________________________________
# u_residual (Subtract)           (None, 3, 4)         0           control_joiner[0][0]
#                                                                  ctrl_decoder_time_dist[0][0]
# __________________________________________________________________________________________________
# x_residual (Subtract)           (None, 4, 165)       0           profile_joiner[0][0]
#                                                                  state_decoder_time_dist[0][0]
# __________________________________________________________________________________________________
# linear_system_residual (Subtrac (None, 3, 20)        0           x1[0][0]
#                                                                  x1est[0][0]
# ==================================================================================================
# Total params: 91,848
# Trainable params: 91,848
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Uses the multi-gpu model if there are more than one gpus

# %%
if ngpu > 1:
    parallel_model = keras.utils.multi_gpu_model(model, gpus=ngpu)

optimizer = optimizers[scenario['optimizer']](
    **scenario['optimizer_kwargs'])

# %% [markdown]
# This is where losses and metrices are defined.

# %%
###############
# Get losses and metrics
###############

#loss = 'mse'
metrics = ['mse','mae']
callbacks = []

# %%
def get_huber_loss_fn(**huber_loss_kwargs):

    def huber_loss(y_true, y_pred, clip_delta=1.0):
      error = y_true - y_pred
      cond  = keras.backend.abs(error) < clip_delta

      squared_loss = 0.5 * keras.backend.square(error)
      linear_loss  = clip_delta * (keras.backend.abs(error) - 0.5 * clip_delta)

      return tf.where(cond, squared_loss, linear_loss)

    def huber_loss_mean(y_true, y_pred, clip_delta=1.0):
      return keras.backend.mean(huber_loss(y_true, y_pred, clip_delta))

    return huber_loss_mean

# %% [markdown]
# The callbacks are changing the learning rate

# %%
callbacks.append(ReduceLROnPlateau(monitor='val_loss', 
                                   factor=0.5, 
                                   patience=5,
                                   verbose=1, 
                                   mode='auto', 
                                   min_delta=0.001,
                                   cooldown=1, 
                                   min_lr=0))

callbacks.append(EarlyStopping(monitor='val_loss', 
                               min_delta=0, 
                               patience=10, 
                               verbose=1, 
                               mode='min'))

callbacks.append(TimingCallback(time_limit=(runtimes[scenario_index]-30)*60))

if ngpu <= 1:
    callbacks.append(ModelCheckpoint(checkpt_dir+scenario['runname']+'.h5', monitor='val_loss',
                                     verbose=0, save_best_only=True,
                                     save_weights_only=False, mode='auto', period=1))

scenario['steps_per_epoch'] = len(train_generator)
scenario['val_steps'] = len(val_generator)
print('Train generator length: {}'.format(len(train_generator)))
# Out:
# Train generator length: 9

# %% [markdown]
# Save with pickle

# %%
###############
# Save scenario
###############
with open(checkpt_dir + scenario['runname'] + '_params.pkl', 'wb+') as f:
    pickle.dump(copy.deepcopy(scenario), f)
print('Saved Analysis params before run')
# Out:
# Saved Analysis params before run

# %% [markdown]
# Finally, we train the model.

# %%
###############
# Compile and Train
###############
if ngpu > 1:
    parallel_model.compile(optimizer, get_huber_loss_fn(delta=0.1), metrics,
                           sample_weight_mode="temporal")
    print('Parallel model compiled, starting training')
    history = parallel_model.fit_generator(train_generator,
                                           steps_per_epoch=scenario['steps_per_epoch'],
                                           epochs=scenario['epochs'],
                                           callbacks=callbacks,
                                           validation_data=val_generator,
                                           validation_steps=scenario['val_steps'],
                                           verbose=0)
else:
    model.compile(optimizer, get_huber_loss_fn(delta=0.1), metrics, sample_weight_mode="temporal")
    print('Model compiled, starting training')
    history = model.fit_generator(train_generator,
                                  steps_per_epoch=scenario['steps_per_epoch'],
                                  epochs=scenario['epochs'],
                                  callbacks=callbacks,
                                  validation_data=val_generator,
                                  validation_steps=scenario['val_steps'],
                                  verbose=0)
# Out:
# Model compiled, starting training

# %% [markdown]
# This part saves the result.

# %%
 ###############
# Save Results
###############
scenario['model_path'] = checkpt_dir + scenario['runname'] + '.h5'
scenario['history'] = history.history
scenario['history_params'] = history.params

write_autoencoder_results(model, scenario)

if not any([isinstance(cb, ModelCheckpoint) for cb in callbacks]):
    model.save(scenario['model_path'])
    print('Saved model after training')
with open(checkpt_dir + scenario['runname'] + '_params.pkl', 'wb+') as f:
    pickle.dump(copy.deepcopy(scenario), f)
print('Saved Analysis params after training')
# Out:
# Couldn't connect to gsheet for scenario: model-autoencoder_SET-dense_SDT-dense_CET-dense_CDT-dense_profiles-temp-dens-ffprime_EFIT02-press_EFIT02-q_EFIT02_act-pinj-curr-tinj-gasA_LB-0_LA-3_17Nov20-09-26_Scenario-1
# Couldn't generate images for scenario: model-autoencoder_SET-dense_SDT-dense_CET-dense_CDT-dense_profiles-temp-dens-ffprime_EFIT02-press_EFIT02-q_EFIT02_act-pinj-curr-tinj-gasA_LB-0_LA-3_17Nov20-09-26_Scenario-1
# Saved Analysis params after training

# %%
with open(checkpt_dir + scenario['runname'] + '_params.pkl', 'rb') as f:
    data = pickle.load(f,encoding='latin1')

# %%
print(history.history)
# Out:
# {'val_loss': [0.322540169176848, 0.25091586812682776, 0.22274862488974695], 'val_u_residual_loss': [0.2837807413028634, 0.22062125105572783, 0.19823251786115376], 'val_x_residual_loss': [0.02625116835469785, 0.01520895312094818, 0.01840089962048375], 'val_linear_system_residual_loss': [0.012508257514918629, 0.015085665372443264, 0.006115203935895925], 'val_u_residual_mean_squared_error': [0.2837807413028634, 0.22062125105572783, 0.19823251786115376], 'val_u_residual_mean_absolute_error': [0.31583643218745355, 0.262393096866815, 0.2551404147044472], 'val_x_residual_mean_squared_error': [0.2625116783639659, 0.1520895300352055, 0.18400899385628494], 'val_x_residual_mean_absolute_error': [0.3775624075661535, 0.26673347988854285, 0.31293055285578186], 'val_linear_system_residual_mean_squared_error': [0.012508257514918629, 0.015085665372443264, 0.006115203935895925], 'val_linear_system_residual_mean_absolute_error': [0.08760253469581189, 0.08870968238815018, 0.06191022564535555], 'loss': [1.5277049101475213, 1.168613603628344, 1.066120845389863], 'u_residual_loss': [1.3026570862780014, 1.1328072891053227, 1.0418972741657246], 'x_residual_loss': [0.04354263980769449, 0.024188980056593815, 0.016979380272742775], 'linear_system_residual_loss': [0.18150518322104794, 0.011617338352112306, 0.007244189564759532], 'u_residual_mean_squared_error': [1.3026570862780014, 1.1328072891053227, 1.0418972741657246], 'u_residual_mean_absolute_error': [0.5328036929170291, 0.42651287267605464, 0.3849095956318908], 'x_residual_mean_squared_error': [0.43542639373077285, 0.24188979632324642, 0.1697938010510471], 'x_residual_mean_absolute_error': [0.48446605536672804, 0.34409451435009636, 0.2716963373952442], 'linear_system_residual_mean_squared_error': [0.18150518322104794, 0.011617338352112306, 0.007244189564759532], 'linear_system_residual_mean_absolute_error': [0.23005428438385328, 0.08200597738226255, 0.06385307937032647], 'lr': [0.01, 0.01, 0.01], 'end_times': [[1601748587.190036, 1601748589.1166685, 1601748590.9369283], [1601748587.190036, 1601748589.1166685, 1601748590.9369283], [1601748587.190036, 1601748589.1166685, 1601748590.9369283]], 'epoch_times': [[2.543987274169922, 1.6686925888061523, 1.6083717346191406], [2.543987274169922, 1.6686925888061523, 1.6083717346191406], [2.543987274169922, 1.6686925888061523, 1.6083717346191406]]}

# %%
data
# Out:
# {'x_weight': 0.1,
#  'u_weight': 1,
#  'discount_factor': 1.0,
#  'state_latent_dim': 20,
#  'control_latent_dim': 5,
#  'state_encoder_kwargs': {'num_layers': 6,
#   'layer_scale': 2,
#   'std_activation': 'elu'},
#  'state_decoder_kwargs': {'num_layers': 6,
#   'layer_scale': 2,
#   'std_activation': 'elu'},
#  'control_encoder_kwargs': {'num_layers': 10,
#   'layer_scale': 1,
#   'std_activation': 'elu'},
#  'control_decoder_kwargs': {'num_layers': 10,
#   'layer_scale': 1,
#   'std_activation': 'elu'},
#  'actuator_names': ['pinj', 'curr', 'tinj', 'gasA'],
#  'profile_names': ['temp',
#   'dens',
#   'ffprime_EFIT02',
#   'press_EFIT02',
#   'q_EFIT02'],
#  'scalar_names': [],
#  'profile_downsample': 2,
#  'state_encoder_type': 'dense',
#  'state_decoder_type': 'dense',
#  'control_encoder_type': 'dense',
#  'control_decoder_type': 'dense',
#  'batch_size': 1,
#  'epochs': 3,
#  'flattop_only': True,
#  'raw_data_path': '/scratch/gpfs/jabbate/small_data.pkl',
#  'process_data': True,
#  'optimizer': 'adagrad',
#  'optimizer_kwargs': {},
#  'shuffle_generators': True,
#  'pruning_functions': [<function helpers.pruning_functions.remove_nan(data, verbose)>,
#   <function helpers.pruning_functions.remove_dudtrip(data, verbose)>,
#   <function helpers.pruning_functions.remove_I_coil(data, verbose)>],
#  'normalization_method': 'RobustScaler',
#  'window_length': 3,
#  'window_overlap': 0,
#  'lookback': 0,
#  'lookahead': 3,
#  'sample_step': 1,
#  'uniform_normalization': True,
#  'train_frac': 0.8,
#  'val_frac': 0.2,
#  'nshots': 12000,
#  'excluded_shots': ['topology_TOP',
#   'topology_OUT',
#   'topology_MAR',
#   'topology_IN',
#   'topology_DN',
#   'topology_BOT'],
#  'sig_names': ['temp',
#   'dens',
#   'ffprime_EFIT02',
#   'press_EFIT02',
#   'q_EFIT02',
#   'pinj',
#   'curr',
#   'tinj',
#   'gasA'],
#  'dt': 0.15,
#  'normalization_dict': {'C_coil_method': {'nanmean': 5.0,
#    'method': 'RobustScaler',
#    'median': 5.0,
#    'iqr': 0.0},
#   'I_coil_method': {'nanmean': -0.30088496,
#    'method': 'RobustScaler',
#    'median': 0.0,
#    'iqr': 1.0},
#   'bt': {'nanmean': -2.0494745,
#    'method': 'RobustScaler',
#    'median': -2.0536156,
#    'iqr': 0.043602705001831055},
#   'curr': {'nanmean': 1440586.8,
#    'method': 'RobustScaler',
#    'median': 1385585.0,
#    'iqr': 837866.0625},
#   'dens': {'nanmean': array([4.0807405, 4.079922 , 4.0779433, 4.074947 , 4.0712852, 4.0671315,
#           4.062568 , 4.057641 , 4.0523376, 4.046719 , 4.040777 , 4.034551 ,
#           4.0280604, 4.021339 , 4.014421 , 4.00733  , 4.000111 , 3.9927905,
#           3.9854195, 3.97803  , 3.970664 , 3.96336  , 3.956164 , 3.9490979,
#           3.9422336, 3.9355736, 3.9291909, 3.923087 , 3.917345 , 3.9119952,
#           3.9070706, 3.902642 , 3.8986492, 3.8951628, 3.8920653, 3.8893344,
#           3.886819 , 3.8843844, 3.8817878, 3.878789 , 3.8749113, 3.869871 ,
#           3.8628538, 3.853401 , 3.8404875, 3.8231678, 3.800501 , 3.770667 ,
#           3.7333016, 3.6852498, 3.6268044, 3.555133 , 3.4700277, 3.3705175,
#           3.2564132, 3.1298735, 2.99174  , 2.8458114, 2.6898646, 2.5126417,
#           2.281547 , 1.9595662, 1.5484159, 1.1237062, 0.7757027],
#          dtype=float32),
#    'method': 'RobustScaler',
#    'median': 3.5903585,
#    'iqr': 2.001324415206909},
#   'dud_trip': {'nanmean': 0.0,
#    'method': 'RobustScaler',
#    'median': 0.0,
#    'iqr': 0.0},
#   'ffprime_EFIT02': {'nanmean': array([-0.73680174, -0.96377105, -1.1453635 , -1.2882442 , -1.3981425 ,
#           -1.4799676 , -1.537953  , -1.57574   , -1.5964786 , -1.6029077 ,
#           -1.597407  , -1.5820727 , -1.5587531 , -1.5290996 , -1.4946246 ,
#           -1.4567046 , -1.4166394 , -1.3756757 , -1.3350369 , -1.2959591 ,
#           -1.2595547 , -1.2258698 , -1.1944995 , -1.165094  , -1.1373575 ,
#           -1.1110274 , -1.0858848 , -1.0617262 , -1.0383853 , -1.0157113 ,
#           -0.9935663 , -0.9718281 , -0.95038563, -0.92913175, -0.9079698 ,
#           -0.8867978 , -0.8655204 , -0.844034  , -0.82223463, -0.800006  ,
#           -0.77722627, -0.75375617, -0.72944176, -0.7041067 , -0.67755216,
#           -0.6495467 , -0.6198263 , -0.5880813 , -0.5539562 , -0.5170352 ,
#           -0.47683442, -0.43279   , -0.384244  , -0.33042789, -0.27044535,
#           -0.203248  , -0.12761149, -0.042105  ,  0.05494361,  0.16548929,
#            0.2918169 ,  0.43659696,  0.6029526 ,  0.7945326 ,  1.0156065 ],
#          dtype=float32),
#    'method': 'RobustScaler',
#    'median': -0.75209874,
#    'iqr': 1.4664199352264404},
#   'gasA': {'nanmean': 0.7226417,
#    'method': 'RobustScaler',
#    'median': 0.06371413,
#    'iqr': 0.7115463604786783},
#   'pinj': {'nanmean': 6651.735,
#    'method': 'RobustScaler',
#    'median': 4820.778,
#    'iqr': 9785.69384765625},
#   'press_EFIT02': {'nanmean': array([87387.92  , 83985.84  , 80767.984 , 77721.89  , 74836.14  ,
#           72100.04  , 69503.836 , 67038.27  , 64694.83  , 62465.84  ,
#           60344.01  , 58322.438 , 56394.875 , 54555.535 , 52799.055 ,
#           51120.23  , 49514.48  , 47977.4   , 46504.77  , 45093.01  ,
#           43738.277 , 42437.12  , 41186.676 , 39983.656 , 38825.395 ,
#           37709.07  , 36632.168 , 35592.203 , 34586.72  , 33613.562 ,
#           32670.484 , 31755.21  , 30865.71  , 29999.83  , 29155.45  ,
#           28330.484 , 27522.912 , 26730.506 , 25951.121 , 25182.617 ,
#           24422.59  , 23668.768 , 22918.613 , 22169.63  , 21419.12  ,
#           20664.217 , 19901.984 , 19129.26  , 18342.658 , 17538.652 ,
#           16713.404 , 15862.816 , 14982.608 , 14068.067 , 13114.222 ,
#           12115.673 , 11066.614 ,  9960.893 ,  8791.778 ,  7552.0615,
#            6233.9727,  4829.135 ,  3328.4924,  1722.2933,     0.    ],
#          dtype=float32),
#    'method': 'RobustScaler',
#    'median': 17187.504,
#    'iqr': 51801.8447265625},
#   'q_EFIT02': {'nanmean': array([1.0818434, 1.0710487, 1.0570652, 1.0491866, 1.0452449, 1.0453483,
#           1.0469202, 1.0507046, 1.0563575, 1.0637255, 1.072714 , 1.0831522,
#           1.0949696, 1.1073724, 1.120078 , 1.1337334, 1.1486479, 1.1648824,
#           1.1824694, 1.2013557, 1.2215345, 1.2429341, 1.2655047, 1.2891936,
#           1.3139611, 1.3397908, 1.3666595, 1.394524 , 1.4233904, 1.4532431,
#           1.4840654, 1.5158477, 1.5485681, 1.5822346, 1.6168325, 1.6523527,
#           1.6887952, 1.7261616, 1.7644544, 1.8036977, 1.8438959, 1.8850936,
#           1.9273379, 1.9707171, 2.0153162, 2.0612328, 2.108684 , 2.1578462,
#           2.2090023, 2.2623909, 2.3184545, 2.3776455, 2.4406643, 2.5082207,
#           2.581396 , 2.6613727, 2.749681 , 2.8481538, 2.9596965, 3.088503 ,
#           3.2418368, 3.433258 , 3.6920612, 4.1037574, 6.2423673],
#          dtype=float32),
#    'method': 'RobustScaler',
#    'median': 1.5684226,
#    'iqr': 1.3363803625106812},
#   'temp': {'nanmean': array([3.8963337 , 3.893495  , 3.8860035 , 3.8733459 , 3.8560784 ,
#           3.8342185 , 3.8078253 , 3.7773964 , 3.7425747 , 3.704152  ,
#           3.6617045 , 3.6159153 , 3.5666766 , 3.5142808 , 3.458986  ,
#           3.4007747 , 3.340183  , 3.276985  , 3.2117922 , 3.144534  ,
#           3.0755813 , 3.005083  , 2.9332333 , 2.8603191 , 2.786438  ,
#           2.7119186 , 2.6368873 , 2.5616088 , 2.4862573 , 2.4110513 ,
#           2.3361597 , 2.2618158 , 2.1880999 , 2.115331  , 2.0434935 ,
#           1.9728613 , 1.9034743 , 1.8354801 , 1.769027  , 1.7040708 ,
#           1.6408904 , 1.57928   , 1.5195309 , 1.4614316 , 1.4050967 ,
#           1.3504407 , 1.2973619 , 1.2458863 , 1.1957248 , 1.1469959 ,
#           1.0993524 , 1.0528293 , 1.0072463 , 0.96254426, 0.9186166 ,
#           0.87514186, 0.8310628 , 0.78378654, 0.7244635 , 0.6367064 ,
#           0.48911968, 0.29408035, 0.137615  , 0.06288984, 0.03063507],
#          dtype=float32),
#    'method': 'RobustScaler',
#    'median': 1.8509552,
#    'iqr': 2.247390925884247},
#   'tinj': {'nanmean': 5.296322,
#    'method': 'RobustScaler',
#    'median': 3.6959288,
#    'iqr': 7.007903099060059}},
#  'profile_length': 33,
#  'runname': 'model-autoencoder_SET-dense_SDT-dense_CET-dense_CDT-dense_profiles-temp-dens-ffprime_EFIT02-press_EFIT02-q_EFIT02_act-pinj-curr-tinj-gasA_LB-0_LA-3_03Oct20-14-09_Scenario-1',
#  'steps_per_epoch': 90,
#  'val_steps': 23,
#  'model_path': '/home/aiqtidar/run_results_10_02/model-autoencoder_SET-dense_SDT-dense_CET-dense_CDT-dense_profiles-temp-dens-ffprime_EFIT02-press_EFIT02-q_EFIT02_act-pinj-curr-tinj-gasA_LB-0_LA-3_03Oct20-14-09_Scenario-1.h5',
#  'history': {'val_loss': [0.322540169176848,
#    0.25091586812682776,
#    0.22274862488974695],
#   'val_u_residual_loss': [0.2837807413028634,
#    0.22062125105572783,
#    0.19823251786115376],
#   'val_x_residual_loss': [0.02625116835469785,
#    0.01520895312094818,
#    0.01840089962048375],
#   'val_linear_system_residual_loss': [0.012508257514918629,
#    0.015085665372443264,
#    0.006115203935895925],
#   'val_u_residual_mean_squared_error': [0.2837807413028634,
#    0.22062125105572783,
#    0.19823251786115376],
#   'val_u_residual_mean_absolute_error': [0.31583643218745355,
#    0.262393096866815,
#    0.2551404147044472],
#   'val_x_residual_mean_squared_error': [0.2625116783639659,
#    0.1520895300352055,
#    0.18400899385628494],
#   'val_x_residual_mean_absolute_error': [0.3775624075661535,
#    0.26673347988854285,
#    0.31293055285578186],
#   'val_linear_system_residual_mean_squared_error': [0.012508257514918629,
#    0.015085665372443264,
#    0.006115203935895925],
#   'val_linear_system_residual_mean_absolute_error': [0.08760253469581189,
#    0.08870968238815018,
#    0.06191022564535555],
#   'loss': [1.5277049101475213, 1.168613603628344, 1.066120845389863],
#   'u_residual_loss': [1.3026570862780014,
#    1.1328072891053227,
#    1.0418972741657246],
#   'x_residual_loss': [0.04354263980769449,
#    0.024188980056593815,
#    0.016979380272742775],
#   'linear_system_residual_loss': [0.18150518322104794,
#    0.011617338352112306,
#    0.007244189564759532],
#   'u_residual_mean_squared_error': [1.3026570862780014,
#    1.1328072891053227,
#    1.0418972741657246],
#   'u_residual_mean_absolute_error': [0.5328036929170291,
#    0.42651287267605464,
#    0.3849095956318908],
#   'x_residual_mean_squared_error': [0.43542639373077285,
#    0.24188979632324642,
#    0.1697938010510471],
#   'x_residual_mean_absolute_error': [0.48446605536672804,
#    0.34409451435009636,
#    0.2716963373952442],
#   'linear_system_residual_mean_squared_error': [0.18150518322104794,
#    0.011617338352112306,
#    0.007244189564759532],
#   'linear_system_residual_mean_absolute_error': [0.23005428438385328,
#    0.08200597738226255,
#    0.06385307937032647],
#   'lr': [0.01, 0.01, 0.01],
#   'end_times': [[1601748587.190036, 1601748589.1166685, 1601748590.9369283],
#    [1601748587.190036, 1601748589.1166685, 1601748590.9369283],
#    [1601748587.190036, 1601748589.1166685, 1601748590.9369283]],
#   'epoch_times': [[2.543987274169922, 1.6686925888061523, 1.6083717346191406],
#    [2.543987274169922, 1.6686925888061523, 1.6083717346191406],
#    [2.543987274169922, 1.6686925888061523, 1.6083717346191406]]},
#  'history_params': {'epochs': 3,
#   'steps': 90,
#   'verbose': 1,
#   'do_validation': True,
#   'metrics': ['loss',
#    'u_residual_loss',
#    'x_residual_loss',
#    'linear_system_residual_loss',
#    'u_residual_mean_squared_error',
#    'u_residual_mean_absolute_error',
#    'x_residual_mean_squared_error',
#    'x_residual_mean_absolute_error',
#    'linear_system_residual_mean_squared_error',
#    'linear_system_residual_mean_absolute_error',
#    'val_loss',
#    'val_u_residual_loss',
#    'val_x_residual_loss',
#    'val_linear_system_residual_loss',
#    'val_u_residual_mean_squared_error',
#    'val_u_residual_mean_absolute_error',
#    'val_x_residual_mean_squared_error',
#    'val_x_residual_mean_absolute_error',
#    'val_linear_system_residual_mean_squared_error',
#    'val_linear_system_residual_mean_absolute_error']},
#  'image_path': 'https://jabbate7.github.io/plasma-profile-predictor/results/model-autoencoder_SET-dense_SDT-dense_CET-dense_CDT-dense_profiles-temp-dens-ffprime_EFIT02-press_EFIT02-q_EFIT02_act-pinj-curr-tinj-gasA_LB-0_LA-3_03Oct20-14-09_Scenario-1'}
