# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# dirname = '/global/cscratch1/sd/abbatej/autoruns/mar3_fixed_final_dens'
# subdirname = 'numlayers_2_densact_relu_denssize_40'
dirname = '/global/homes/a/abbatej/'
subdirname = 'plasma_profiles_predictor'

# %%
filename=os.path.join(dirname,subdirname,'history.npz')
data=np.load(filename)

# %%
print([i for i in data])
# Out:
# ['n_ranks', 'val_loss', 'val_mean_absolute_error', 'loss', 'mean_absolute_error']

# %%
plt.plot(data['mean_absolute_error'], 'b')
plt.plot(data['val_mean_absolute_error'], 'r')
plt.show()
